# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class Load_Preprocess():
    def __init__(self, path='C:/Users/abdelFerdous/Desktop/integrify/ML_projects/ML_group8_project/dataset.csv'):
        self.df = pd.read_csv(path)
        self.check_data()
        
    def check_data(self):
        print("##################### Shape #####################")
        print(self.df.shape)
        print("##################### Info #####################")
        print(self.df.info())
        print("##################### Null Val #####################")
        print(self.df.isnull().sum())
        print("##################### unique values #####################")
        print(self.df.nunique())
        print("##################### unique values #####################")
        print(self.df.describe())
        
    def plot_features(self ,data , feature):
        sns.set(style="whitegrid")

        plt.figure(figsize=(10, 6))
        sns.countplot(x=feature, hue='group', data=data, palette='Set2')

        plt.title(f'Distribution of {feature} by Group')
        plt.xlabel(f'{feature}')
        plt.ylabel('Count')
        if feature == 'Initial_Symptom':
            plt.xticks(rotation=60)

        plt.legend(title='Group', loc='upper right', labels=['CDMS', 'non-CDMS'])
        plt.show()
        return data.groupby([feature, 'group'])['group'].count()

# %%
LP = Load_Preprocess()
LP.df
# Out:
# ##################### Shape #####################
# (273, 20)
# ##################### Info #####################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               273 non-null    int64
#  1   Gender                   273 non-null    int64
#  2   Age                      273 non-null    int64
#  3   Schooling                272 non-null    float64
#  4   Breastfeeding            273 non-null    int64
#  5   Varicella                273 non-null    int64
#  6   Initial_Symptom          272 non-null    float64
#  7   Mono_or_Polysymptomatic  273 non-null    int64
#  8   Oligoclonal_Bands        273 non-null    int64
#  9   LLSSEP                   273 non-null    int64
#  10  ULSSEP                   273 non-null    int64
#  11  VEP                      273 non-null    int64
# ...

# %% [markdown]
# ID: Patient identifier (int)
#
# Age: Age of the patient (in years)
#
# Schooling: time the patient spent in school (in years)
#
# Gender: 1=male, 2=female
#
# Breastfeeding: 1=yes, 2=no, 3=unknown
#
# Varicella: 1=positive, 2=negative, 3=unknown
#
# Initial_Symptoms: 1=visual, 2=sensory, 3=motor, 4=other, 5= visual and sensory, 6=visual and motor, 7=visual and others, 8=sensory and motor, 9=sensory and other, 10=motor and other, 11=Visual, sensory and motor, 12=visual, sensory and other, 13=Visual, motor and other, 14=Sensory, motor and other, 15=visual,sensory,motor and other
#
# Mono _or_Polysymptomatic: 1=monosymptomatic, 2=polysymptomatic, 3=unknown
#
# Oligoclonal_Bands: 0=negative, 1=positive, 2=unknown
#
# LLSSEP: 0=negative, 1=positive
#
# ULSSEP:0=negative, 1=positive
#
# VEP:0=negative, 1=positive
#
# BAEP: 0=negative, 1=positive
#
# Periventricular_MRI:0=negative, 1=positive
#
# Cortical_MRI: 0=negative, 1=positive
#
# Infratentorial_MRI:0=negative, 1=positive
#
# Spinal_Cord_MRI: 0=negative, 1=positive
#
# initial_EDSS:?
#
# final_EDSS:?
#
# Group: 1=CDMS, 2=non-CDMS
#
# ############################################
#
# Varicella : Another name for Chickenpox, or chicken pox, is a highly contagious disease caused by the initial infection with varicella zoster virus (VZV), a member of the herpesvirus family.
#
# BAEP: In human neuroanatomy, brainstem auditory evoked potentials (BAEPs), also called brainstem auditory evoked responses (BAERs), are very small auditory evoked potentials in response to an auditory stimulus, which are recorded by electrodes placed on the scalp.
#
# VEP: Visual evoked potential (VEP) is an evoked potential elicited by presenting light flash or pattern stimulus which can be used to confirm damage to visual pathway including retina, optic nerve, optic chiasm, optic radiations, and occipital cortex.
#
# Oligoclonal bands: Oligoclonal bands (OCBs) are bands of immunoglobulins that are seen when a patient's blood serum, or cerebrospinal fluid (CSF) is analyzed. They are used in the diagnosis of various neurological and blood diseases. Oligoclonal bands are present in the CSF of more than 95% of patients with clinically definite multiple sclerosis.
#
# SSEP : Somatosensory evoked potentials (SSEP) are recorded from the central nervous system following stimulation of peripheral nerves. ULSSEP (upper limb SSEP), LLSSEP (lower limb SSEP)
#
# EDSS: The Expanded Disability Status Scale (EDSS) is a method of quantifying disability in multiple sclerosis and monitoring changes in the level of disability over time. It is widely used in clinical trials and in the assessment of people with MS.

# %%
data = LP.df.copy()

# %%
gender = {1:'Male', 2: 'Female'}
breastfeeding = {1: 'yes', 2:'no', 3:'unknown'}
varicella = {1 : 'positive', 2: 'negative', 3: 'unknown'}
initial_symptoms= {
    1: 'visual',
    2: 'sensory',
    3: 'motor',
    4: 'other',
    5: 'visual and sensory',
    6: 'visual and motor',
    7: 'visual and others',
    8: 'sensory and motor',
    9: 'sensory and other',
    10: 'motor and other',
    11: 'Visual, sensory and motor',
    12: 'visual, sensory and other',
    13: 'Visual, motor and other',
    14: 'Sensory, motor and other',
    15: 'visual, sensory, motor and other'
}
mono_or_polysymptomatic = {
    1: 'monosymptomatic',
    2: 'polysymptomatic',
    3: 'unknown'
}
oligoclonal_bands = {
    0: 'negative',
    1: 'positive',
    2: 'unknown'
}
binary = {
    0: 'negative',
    1: 'positive'
}
group = {1: 'CDMS' , 2: 'Non-CDMS' }

data['Gender'] = data['Gender'].map(gender)
data['Breastfeeding'] = data['Breastfeeding'].map(breastfeeding)
data['Varicella'] = data['Varicella'].map(varicella)
data['Initial_Symptom'] = data['Initial_Symptom'].map(initial_symptoms)
data['Mono_or_Polysymptomatic'] = data['Mono_or_Polysymptomatic'].map(mono_or_polysymptomatic)
data['Oligoclonal_Bands'] = data['Oligoclonal_Bands'].map(oligoclonal_bands)
features_to_map = ['LLSSEP', 'ULSSEP', 'VEP', 'BAEP', 'Periventricular_MRI', 'Cortical_MRI', 'Infratentorial_MRI', 'Spinal_Cord_MRI']
for feature in features_to_map:
    data[feature] = data[feature].map(binary)
data['group'] = data['group'].map(group)
data.head(10)
# Out:
#    Unnamed: 0  Gender  Age  Schooling Breastfeeding Varicella  \
# 0           0    Male   34       20.0           yes  positive
# 1           1    Male   61       25.0       unknown  negative
# 2           2    Male   22       20.0       unknown  positive
# 3           3  Female   41       15.0           yes  positive
# 4           4  Female   34       20.0            no  positive
# 5           5    Male   29       22.0           yes  positive
# 6           6  Female   53       20.0           yes  positive
# 7           7  Female   24       15.0           yes  positive
# 8           8    Male   36       15.0           yes  positive
# 9           9  Female   28       20.0           yes  positive
#
#             Initial_Symptom Mono_or_Polysymptomatic Oligoclonal_Bands  \
# 0                   sensory         monosymptomatic          negative
# 1           motor and other         polysymptomatic          positive
# 2                     motor         monosymptomatic          positive
# ...

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
sns.countplot(x='group', data=data, palette='pastel')

plt.title('Count Plot for Group')
plt.xlabel('Group ')
plt.ylabel('Count')
plt.show()
print('No-CDMS', round(data['group'].value_counts()['Non-CDMS']/len(data) * 100,2), '% of the dataset')
print('CDMS', round(data['group'].value_counts()['CDMS']/len(data) * 100,2), '% of the dataset')
print("thus the dataset is well balanced")
# Out:
# C:\Users\abdelFerdous\AppData\Local\Temp\ipykernel_13832\2575380685.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='group', data=data, palette='pastel')
# No-CDMS 54.21 % of the dataset
# CDMS 45.79 % of the dataset
# thus the dataset is well balanced

# %%
sns.set(style="whitegrid")

# Countplot for Gender and Group
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', hue='group', data=data, palette='viridis')

# Adding labels and title
plt.title('Distribution of Gender in Each Group')
plt.xlabel('Gender')
plt.ylabel('Count')

# Adding legend
plt.legend(title='Group', loc='upper right', labels=['CDMS', 'Non-CDMS'])

# Show the plot
plt.show()
data.groupby(['Gender', 'group'] )['group'].count()
# Out:
# Gender  group
# Female  CDMS         61
#         Non-CDMS    107
# Male    CDMS         64
#         Non-CDMS     41
# Name: group, dtype: int64

# %%
LP.plot_features(data , 'Varicella')

# %% [markdown]
# Varicella : Another name for Chickenpox, or chicken pox, is a highly contagious disease caused by the initial infection with varicella zoster virus (VZV), a member of the herpesvirus family.

# %%
sns.set(style="whitegrid")

# Create age bins
age_bins = [0, 20,40,60,80]
age_labels = ['0-20', '20-40', '40-60', '60-80']
data['AgeGroup'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels, right=False)

# Countplot for Age Group
plt.figure(figsize=(10, 6))
sns.countplot(x='AgeGroup', hue='group', data=data, palette='viridis')

# Adding labels and title
plt.title('Distribution of Age Groups by Group ')
plt.xlabel('Age Group')
plt.ylabel('Count')

# Show the plot
plt.show()
data['Age'].describe()
# Out:
# count    273.000000
# mean      34.062271
# std       11.114369
# min       15.000000
# 25%       25.000000
# 50%       33.000000
# 75%       40.000000
# max       77.000000
# Name: Age, dtype: float64

# %%
f = [
    'Initial_Symptom',
    'Mono_or_Polysymptomatic',
    'Oligoclonal_Bands',
    'LLSSEP',
    'ULSSEP',
    'VEP',
    'BAEP',
    'Periventricular_MRI',
    'Cortical_MRI',
    'Infratentorial_MRI',
    'Spinal_Cord_MRI',
    'Initial_EDSS',
    'Final_EDSS'
]

for feature in f:
    counts =LP.plot_features(data , feature)
    print(counts)
# Out:
# Initial_Symptom                   group
# Sensory, motor and other          CDMS        11
#                                   Non-CDMS     3
# Visual, motor and other           CDMS        10
#                                   Non-CDMS     1
# Visual, sensory and motor         CDMS         9
#                                   Non-CDMS     1
# motor                             CDMS        15
#                                   Non-CDMS    17
# motor and other                   CDMS         8
#                                   Non-CDMS     7
# other                             CDMS        13
#                                   Non-CDMS    17
# sensory                           CDMS         3
#                                   Non-CDMS    23
# sensory and motor                 CDMS        17
#                                   Non-CDMS    22
# sensory and other                 CDMS         3
#                                   Non-CDMS     5
# ...

# %%
corr = LP.df.drop('Unnamed: 0', axis=1).corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
fi, ax = plt.subplots(figsize=(14, 9), facecolor=None)
cmap = sns.color_palette('coolwarm', as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin=-1.0, center=0, annot=True,
            square=False, linewidths=.5, cbar_kws={"shrink": 0.75})
ax.set_title("Pearson's Correlation Heatmap", fontsize=16, y= 1.05);

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %%
x = LP.df[[
    'Gender',
    'Age',
    'Varicella',
    'Initial_Symptom',
    'Mono_or_Polysymptomatic',
    'Oligoclonal_Bands',
    'LLSSEP',
    'ULSSEP',
    'VEP',
    'BAEP',
    'Periventricular_MRI',
    'Cortical_MRI',
    'Infratentorial_MRI',
    'Spinal_Cord_MRI',
]]
x.loc[:, 'Initial_Symptom'] = x['Initial_Symptom'].fillna(0)
y = LP.df[['group']]
x.shape , y.shape
# Out:
# ((273, 14), (273, 1))

# %%
x.isnull().sum()
# Out:
# Gender                     0
# Age                        0
# Varicella                  0
# Initial_Symptom            0
# Mono_or_Polysymptomatic    0
# Oligoclonal_Bands          0
# LLSSEP                     0
# ULSSEP                     0
# VEP                        0
# BAEP                       0
# Periventricular_MRI        0
# Cortical_MRI               0
# Infratentorial_MRI         0
# Spinal_Cord_MRI            0
# dtype: int64

# %%
x_train , x_test , y_train, y_test = train_test_split(x ,y.to_numpy().ravel(), test_size=0.2, random_state=42)
x_train.shape , x_test.shape , y_train.shape, y_test.shape
# Out:
# ((218, 14), (55, 14), (218,), (55,))

# %%
clf = LazyClassifier()
models, predictions = clf.fit(x_train, x_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 26.19it/s]
# [LightGBM] [Info] Number of positive: 119, number of negative: 99
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 91
# [LightGBM] [Info] Number of data points in the train set: 218, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.545872 -> initscore=0.184004
# [LightGBM] [Info] Start training from score 0.184004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model_names = []
testing_accuracies = []
cross_val_accuracies = []

# %% [markdown]
# **RandomForestClassifier**

# %%
RFC_model = RandomForestClassifier()

RFC_model.fit(x_train, y_train)

y_pred = RFC_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on the Testing Set: {accuracy:.2f}")
scores = cross_val_score(RFC_model, x_train, y_train, cv=5)
print("Cross-Validation Scores:", scores)
mean_accuracy = scores.mean()
print(f"Mean Accuracy: {mean_accuracy:.2f}")
model_names.append('RFC_model')
testing_accuracies.append(scores)
cross_val_accuracies.append(mean_accuracy)
# Out:
# Accuracy on the Testing Set: 0.76
# Cross-Validation Scores: [0.70454545 0.70454545 0.77272727 0.8372093  0.79069767]
# Mean Accuracy: 0.76

# %% [markdown]
# **AdaBoostClassifier**

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_model = AdaBoostClassifier()

ada_model.fit(x_train, y_train)

y_pred = ada_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on the Testing Set: {accuracy:.2f}")
scores = cross_val_score(ada_model, x_train, y_train, cv=5)
print("Cross-Validation Scores:", scores)
mean_accuracy = scores.mean()
print(f"Mean Accuracy: {mean_accuracy:.2f}")
model_names.append('Ada_model')
testing_accuracies.append(scores)
cross_val_accuracies.append(mean_accuracy)
# Out:
# Accuracy on the Testing Set: 0.82
# Cross-Validation Scores: [0.75       0.75       0.79545455 0.93023256 0.8372093 ]
# Mean Accuracy: 0.81

# %% [markdown]
# **SVC**

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()

svc_model.fit(x_train, y_train)

y_pred = svc_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on the Testing Set: {accuracy:.2f}")
scores = cross_val_score(svc_model, x_train, y_train, cv=5)
print("Cross-Validation Scores:", scores)
mean_accuracy = scores.mean()
print(f"Mean Accuracy: {mean_accuracy:.2f}")
model_names.append('SVC_model')
testing_accuracies.append(scores)
cross_val_accuracies.append(mean_accuracy)
# Out:
# Accuracy on the Testing Set: 0.60
# Cross-Validation Scores: [0.70454545 0.63636364 0.79545455 0.72093023 0.58139535]
# Mean Accuracy: 0.69

# %% [markdown]
# **PERCEPTRON**

# %%
from sklearn.linear_model import Perceptron

# %%
ptr_model = Perceptron()

ptr_model.fit(x_train, y_train)

y_pred = ptr_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on the Testing Set: {accuracy:.2f}")
scores = cross_val_score(ptr_model, x_train, y_train, cv=5)
print("Cross-Validation Scores:", scores)
mean_accuracy = scores.mean()
print(f"Mean Accuracy: {mean_accuracy:.2f}")
model_names.append('ptr_model')
testing_accuracies.append(scores)
cross_val_accuracies.append(mean_accuracy)
# Out:
# Accuracy on the Testing Set: 0.65
# Cross-Validation Scores: [0.72727273 0.70454545 0.75       0.81395349 0.44186047]
# Mean Accuracy: 0.69

# %% [markdown]
# **GRIDSEARCH**

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0]
}

grid_search = GridSearchCV(estimator= ada_model,
                           param_grid=param_grid,
                           scoring='accuracy',
                           cv=5)  

grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print("Best Hyperparameters:", best_params)

best_predictions = best_model.predict(x_test)
best_accuracy = accuracy_score(y_test, best_predictions)
print(f'Best Model Accuracy: {best_accuracy*100:.2f}')

cv_scores = cross_val_score(best_model, x_train, y_train, cv=5, scoring='f1')
print("Cross-Validation Scores:", cv_scores)

mean_accuracy = cv_scores.mean()
print(f"Mean Accuracy: {mean_accuracy:.2f}")

results = pd.DataFrame(grid_search.cv_results_)
results = results.pivot(index='param_n_estimators', columns='param_learning_rate', values='mean_test_score')

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(results, annot=True, fmt=".3f", cmap="viridis", cbar_kws={'label': 'Mean Test Score'})
plt.title('Grid Search Results for AdaBoostClassifier')
plt.xlabel('Learning Rate')
plt.ylabel('Number of Estimators')
plt.show()
# Out:
# Best Hyperparameters: {'learning_rate': 1.0, 'n_estimators': 200}
# Best Model Accuracy: 76.36
# Cross-Validation Scores: [0.78947368 0.74418605 0.78947368 0.9        0.75675676]
# Mean Accuracy: 0.80

# %%
from sklearn.ensemble import StackingClassifier


base_models = [('rf', RFC_model),
               ('ada', ada_model),
               ('svc' , svc_model),
              ('ptr' , ptr_model)]

stack_clf = StackingClassifier(estimators=base_models, final_estimator=ada_model)
stack_clf.fit(x_train, y_train)

y_pred = stack_clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
scores = cross_val_score(stack_clf, x_train, y_train, cv=5)
print("Cross-Validation Scores:", scores)
mean_accuracy = scores.mean()
print(f"Mean Accuracy: {mean_accuracy:.2f}")
model_names.append('stacking_model')
testing_accuracies.append(scores)
cross_val_accuracies.append(mean_accuracy)
# Out:
# Accuracy: 0.7818181818181819
# Cross-Validation Scores: [0.63636364 0.68181818 0.61363636 0.88372093 0.79069767]
# Mean Accuracy: 0.72

# %%
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35

bar1 = ax.bar(model_names, testing_accuracies, bar_width, label='Testing Set')
bar2 = ax.bar([i + bar_width for i, _ in enumerate(model_names)], cross_val_accuracies, bar_width, label='Cross-Validation')

ax.set_ylabel('Accuracy')
ax.set_title('Model Performance Comparison')
ax.legend()

plt.show()

# %%
feature_importances = ada_model.feature_importances_
sorted_idx = np.argsort(feature_importances)[::-1]

plt.figure(figsize=(12, 6))
sns.barplot(x=feature_importances[sorted_idx], y=x_train.columns[sorted_idx], palette='viridis',hue=x_train.columns[sorted_idx], legend=False)
plt.title('Features Importance')
plt.show()
